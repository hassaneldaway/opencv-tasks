# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
plt.imshow(mpimg.imread("felix-dubois-robert-CuEvrPd3NYc-unsplash (1).jpg"))

# %%
plt.imshow(mpimg.imread("robert-katzki-jbtfM0XBeRc-unsplash.jpg"))
